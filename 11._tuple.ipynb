# %% [markdown]
# # Python Tuples and Tuple methods

# %% [markdown]
# ## What is a Tuple?

# %% [markdown]
# A tuple in Python is an ordered, immutable collection of elements. It is similar to list but once created it's elements cannot be modified.

# %% [markdown]
# ## Creating a Tuple

# %%
#Empty tuple
empty_tuple = ()

# %%
#Tuple with elements
numbers = (1, 2, 3, 4, 5)

# %%
#Mixed data types
mixed_tuple = (1, "Hello", 3.14, True)

# %%
#Single element tuple (comma is necessary)
single_element = (42, )

# %% [markdown]
# ## Tuple Characteristics

# %% [markdown]
# - *Immutable: * Once created, elements cannot be changed
# - *Faster than list: * Accessing elements in a typle is faster than in a list
# - *Can be used as dictionary keys: * Since tuples are immutbale, they ccan used as keys in dictionary

# %%
my_tuple = (10, 20, 30, 40)

# %%
my_tuple
# Out:
# (10, 20, 30, 40)

# %%
type(my_tuple)
# Out:
# tuple

# %%
t = (5, 54, 57, 20)

# %%
t
# Out:
# (5, 54, 57, 20)

# %%
len(t)
# Out:
# 4

# %%
t[3]
# Out:
# 20

# %%
t[2] = 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 t[2] = 10
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## Tuple packing and Unpacking

# %%
#packing
person = ("Alice", 25, "Engineer")

# %%
#Unpacking
name, age, profession = person

# %%
print(name)
# Out:
# Alice

# %%
print(age)
# Out:
# 25

# %% [markdown]
# ## When to use tuple?

# %% [markdown]
# - When you want to unchangeable collection of elements.
# - when you need a faster alternative to lists.
# - When storage heterogeneous data(eg. database records, coordinates)
