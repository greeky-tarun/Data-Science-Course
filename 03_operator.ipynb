# %%
a = 10
b = 4

# %%
a + b
# Out:
# 14

# %%
a - b
# Out:
# 6

# %%
a * b
# Out:
# 40

# %%
a / b
# Out:
# 2.5

# %%
a // b
# Out:
# 2

# %%
a % b
# Out:
# 2

# %%
a ** b
# Out:
# 10000

# %%
a == b
# Out:
# False

# %%
a > b
# Out:
# True

# %%
a < b
# Out:
# False

# %%
a >= b
# Out:
# True

# %%
a <= b
# Out:
# False

# %%
c = 3

# %%
a == c # is a equal to c?
# Out:
# False

# %%
a != c
# Out:
# True

# %%
a = 5

# %%
b = 5

# %%
a >= b
# Out:
# True

# %%
a <= b
# Out:
# True

# %%
b1 = False
b2 = True

# %%
not(b1)
# Out:
# True

# %%
not(b2)
# Out:
# False

# %%
b1 or b2
# Out:
# True

# %%
b1 and b2
# Out:
# False

# %%
# bitwise operator
a & b
# Out:
# 5

# %%
a | b
# Out:
# 5

# %%
a = 45

# %%
a -= 4

# %%
a
# Out:
# 41
