# %%
name = "Tarun"

# %%
name
# Out:
# 'Tarun'

# %%
name.upper()
# Out:
# 'TARUN'

# %%
name.endswith("ar")
# Out:
# False

# %%
name.endswith("un")
# Out:
# True

# %%
name.lower()
# Out:
# 'tarun'

# %%
name.count('a')
# Out:
# 1

# %%
s = "Tarun Kumar"
print(len(s)) #output 11
# Out:
# 11

# %%
s[0:5] # 0 to n-1
# Out:
# 'Tarun'

# %%
s[1:-1]
# Out:
# 'arun Kuma'

# %%
s[1:10]
# Out:
# 'arun Kuma'
