# %% [markdown]
# # Python List and List methods

# %% [markdown]
# ## What is List?

# %% [markdown]
# A list in Python is an ordered, mutable collection of elements. It can contain elements of different types.

# %% [markdown]
# ### Creating a List:

# %%
#Empty list
my_list = []

# %%
#List with elements
numbers = [1, 2, 3, 4, 5, 6]

# %%
#Mixed data types
mixed_list = ["Tarun", 64, 9.67]

# %% [markdown]
# ### Example

# %%
fruits = ["apple", "banana", "cherry"]
fruits.append("orange")
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
fruits.sort()
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
l = [3, 5, 6, 28, 1]

# %%
l[0]
# Out:
# 3

# %%
l[0] = 4

# %%
print(l)
# Out:
# [4, 5, 6, 28, 1]

# %%
l.append(9)

# %%
l
# Out:
# [4, 5, 6, 28, 1, 9]

# %%
l2 = [5, 87]

# %%
l.append(l2)

# %%
l
# Out:
# [4, 5, 6, 28, 1, 9, [5, 87]]

# %%
l.extend(l2)

# %%
l
# Out:
# [4, 5, 6, 28, 1, 9, [5, 87], 5, 87]

# %%
l.insert(1, 200) # insert 200 at index 1

# %%
l
# Out:
# [4, 200, 5, 6, 28, 1, 9, [5, 87], 5, 87]

# %%
l[7]
# Out:
# [5, 87]

# %%
l.pop(7)
# Out:
# [5, 87]

# %%
l
# Out:
# [4, 200, 5, 6, 28, 1, 9, 5, 87]

# %%
l.index(28)
# Out:
# 4

# %%
l.append(5)

# %%
l.count(5)
# Out:
# 3

# %%
l.sort()

# %%
l
# Out:
# [1, 4, 5, 5, 5, 6, 9, 28, 87, 200]

# %%
l.reverse()

# %%
l
# Out:
# [200, 87, 28, 9, 6, 5, 5, 5, 4, 1]

# %%
l1 = [4, 32, 98]

# %%
l + l1
# Out:
# [200, 87, 28, 9, 6, 5, 5, 5, 4, 1, 4, 32, 98]

# %%
if 5 in l:
    print("YES")
# Out:
# YES

# %%
S = "Full-stack-web-developer"

# %%
S
# Out:
# 'Full-stack-web-developer'

# %%
S.split("-")
# Out:
# ['Full', 'stack', 'web', 'developer']
