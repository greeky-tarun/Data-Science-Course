# %% [markdown]
# # Python sets and sets Methods

# %% [markdown]
# ## What is set?
# A set in python is an unordered mutable and unique collection of elements. It doesnot allow duplicate values.

# %% [markdown]
# ## Creating a Set:

# %%
#Empty set (must use set(), not{})
empty_set = set()

# %%
#set with elements
numbers = {1, 2, 3, 4, 5, 6}

# %%
#mixed data types
mixed_set = {1, "Hello", 3.14, True}

# %%
#Creating a set from a list
Unique_numbers = set([1, 2, 3, 4, 4, 5, 6])
print(Unique_numbers)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s = {2, 35, 69, 29, 10, 3, 2, 1}

# %%
s.add(35)

# %%
s
# Out:
# {1, 2, 3, 10, 29, 35, 69}

# %%
s.update([3, 58, 29])

# %%
s
# Out:
# {1, 2, 3, 10, 29, 35, 58, 69}

# %%
s.remove(3)

# %%
s
# Out:
# {1, 2, 10, 29, 35, 58, 69}

# %%
s.discard(2)

# %%
s
# Out:
# {1, 10, 29, 35, 58, 69}

# %%
s.discard(939)

# %%
s
# Out:
# {1, 10, 29, 35, 58, 69}

# %%
s.pop()
# Out:
# 1

# %%
s
# Out:
# {10, 29, 35, 58, 69}

# %%
s.union(Unique_numbers)
# Out:
# {1, 2, 3, 4, 5, 6, 10, 29, 35, 58, 69}

# %%
s.intersection(Unique_numbers)
# Out:
# set()

# %%
sub = {1, 3}

# %%
sub.issubset(s)
# Out:
# False
