# %% [markdown]
# ## Taking input from user

# %%
a = input("Enter the value of a: ") #by default it takes input as string
# Out:
# Enter the value of a:  91

# %%
a
# Out:
# '91'

# %%
b = input("Enter the value of b: ")
# Out:
# Enter the value of b:  73

# %%
a+b
# Out:
# '9173'

# %%
int(a) + int(b)
# Out:
# 164

# %%
c = input()
# Out:
#  56
