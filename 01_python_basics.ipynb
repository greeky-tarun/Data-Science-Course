# %%
a  = 5

# %%
b = 6

# %%
a + b
# Out:
# 11

# %%
str = "Harry"

# %%
print(f"{str} welcome and the number is {a+b}") # This is a concatination
# Out:
# Harry welcome and the number is 11

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(str))
# Out:
# <class 'str'>

# %%
type(str)
# Out:
# str

# %%
a = "43"

# %%
b = "56"

# %%
print(a+b) # concationation
# Out:
# 4356

# %%
print(int(a)+int(b)) #Tyep casting
# Out:
# 99
