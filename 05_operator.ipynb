# %%
result = 10 + 2 * 3

# %%
result
# Out:
# 16

# %%
result = 2 ** 3 ** 2

# %%
result
# Out:
# 512

# %% [markdown]
# ## Order of Evaluation

# %% [raw]
# - **(Exponentiation) has the higehst precedence and is evaluted right to left.
# - *, / , //, and % has lower precend
