# %%
a = 4

# %%
if(a > 53):
    print("Greater")
else:
    print("smaller")
# Out:
# smaller

# %%
a = 41
if a > 50:
    print("Greater than 50")
elif a > 40:
    print("Greater than 40")
elif a > 30:
    print("Greater than 30")
else:
    print("Done!")
# Out:
# Greater than 40

# %% [markdown]
# ## Functions in Python

# %%
def avg(a, b):
    return (a+b)/2

# %%
avg(4, 6)
# Out:
# 5.0

# %%
def avg(a, b = 10):
    return (a+b)/2

# %%
avg(4)
# Out:
# 7.0

# %%
def greet():
    print("Hello Tarun")

# %%
greet()
# Out:
# Hello Tarun
